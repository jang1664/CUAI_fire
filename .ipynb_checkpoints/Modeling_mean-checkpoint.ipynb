# %%
# -*- coding: utf-8 -*- 
from sklearn.metrics import accuracy_score, precision_score,recall_score, confusion_matrix, roc_auc_score, classification_report, f1_score,make_scorer
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.decomposition import PCA
#from sklearn_evaluation import plot
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score, cross_validate
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier, plot_importance
#import xgboost.plot_importance
#from lightgbm import LGBMClassifier,plot_importance
from IPython.core.interactiveshell import InteractiveShell
from imblearn.over_sampling import SMOTE
from sklearn.metrics import make_scorer
from sklearn import metrics
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
InteractiveShell.ast_node_interactivity = 'all'
warnings.filterwarnings(action='ignore')
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.options.display.float_format = '{:.5f}'.format

# %%
def preprocessing_data(file):
    data=pd.read_csv(file)
    df=pd.DataFrame(data)
    
    ###[setup]
    # [wther]
    if 'train' in file:
        def fill_hmdt(df):
            ls_=[95,96,97,30,72,92,16,100,78,98,97,80,85,85,100,95,50,40,65,25,60,60]
            i=0
            for k in df.loc[df.hmdt.isnull()==1,:].index:
                df.loc[k,'hmdt']=ls_[i]
                i+=1
        def fill_wnd_spd(df):
            df['emd']=df['emd_nm'].apply(lambda x: str(x)).apply(lambda x: x[5:8])
            df['month']=df['dt_of_fr'].apply(lambda x: x.split('-')[1])
            df['time']=df['dt_of_fr'].apply(lambda x: x.split('-')[2])
            df['time']=df['time'].apply(lambda x: x[3:5]).apply(lambda x: int(x))

            for i in df.loc[df.wnd_spd.isnull()==1,:].index:
                m=df.loc[i,'month']
                t=df.loc[i,'time']
                e=df.loc[i,'emd']
                df.loc[i,'wnd_spd']=df.loc[(df.month==m)&(df.time==t)&(df.emd==e),'wnd_spd'].mean()
        fill_hmdt(df)
        fill_wnd_spd(df)
    else:
        def fill_hmdt(df):
            ls_=[]
            ls_.append((90+90+85)/3)
            ls_.append((47+58+44)/3)
            ls_.append((90+90+85)/3)
            i=0
            for k in df.loc[df.hmdt.isnull()==1,:].index:
                df.loc[k,'hmdt']=ls_[i]
                i+=1
        def fill_wnd_spd(df):
            df_=df
            df_['month']=df['dt_of_fr'].apply(lambda x: x.split('-')[1])
            df_['time']=df['dt_of_fr'].apply(lambda x: x.split('-')[2])
            df_['time']=df_['time'].apply(lambda x: x[3:5]).apply(lambda x: int(x))

            for i in df.loc[df.wnd_spd.isnull()==1,:].index:
                    m=df_.loc[i,'month']
                    t=df_.loc[i,'time']
                    df.loc[i,'wnd_spd']=df_.loc[(df_.month==m)&(df_.time==t),'wnd_spd'].mean()
        fill_hmdt(df)
        fill_wnd_spd(df)
    
    # dt_of_fr_month(월), dt_of_fr_day(일), dt_of_fr_hour(시간)
    df['dt_of_fr']=pd.to_datetime(df['dt_of_fr'])

    df['dt_of_fr_month']=df['dt_of_fr'].dt.month
    df['dt_of_fr_day']=df['dt_of_fr'].dt.day
    df['dt_of_fr_hour']=df['dt_of_fr'].dt.hour

    # wnd_dr8 풍향(ex-북과 동 사이는 모두 북동)
    def dr8(x):
        if ((x>360-22.5) & (x<=0+22.5)) | ((x==0)|(x==360)):
            return 'N'
        elif (x>45-22.5) & (x<=45+22.5):
            return 'NE'
        elif (x>90-22.5) & (x<=90+22.5):
            return 'E'
        elif (x>135-22.5) & (x<=135+22.5):
            return 'SE'
        elif (x>180-22.5) & (x<=180+22.5):
            return 'S'
        elif (x>225-22.5) & (x<=225+22.5):
            return 'SW'
        elif (x>270-22.5) & (x<=270+22.5):
            return 'W'
        else:
            return 'NW'

    df['wnd_dr8']=df['wnd_drctn'].apply(dr8)
    # [wther]
    
#     # [bldng]
#     df.loc[12642,'dt_of_athrztn']=19800808
#     df.loc[21218,'dt_of_athrztn']=19900712
#     df.loc[26351,'dt_of_athrztn']=19990624
#     df.loc[30954,'dt_of_athrztn']=19820930
#     df.loc[38448,'dt_of_athrztn']=19780421
#     df.loc[53193,'dt_of_athrztn']=19971215

#     # yr_of_athrztn(건물승인년도)
    df['yr_of_athrztn']=df['dt_of_athrztn'].apply(lambda x: str(x)[0:4] if pd.isna(x)==False else x)

    #bldng_yrs (건물연수)
    df['bldng_yrs']=df['yr_of_athrztn'].apply(lambda x: 2019-int(x) if pd.isna(x)==False else x)
    
#     # floors(건물 총 층수)
#     df['floors']=df['ttl_grnd_flr']+df['ttl_dwn_flr']
    # [bldng]
    
    # fr_yn(화재발생) -> 1,0
    dict={"Y":1,"N":0}
    df.fr_yn=df.fr_yn.map(dict)
    ###[setup]
    
    
    ### [fill null and cut]
    # tmprtr
    n=df.loc[df['tmprtr'].isnull(),['tmprtr','emd_nm','dt_of_fr_month','dt_of_fr_hour']]

    def fill_tmprtr(row):
        return df.loc[(df['emd_nm']==row[1]) & (df['dt_of_fr_month']==row[2]) & (df['dt_of_fr_hour']==row[3]),'tmprtr'].mean()

    def fill_tmprtr2(row):
        return df.loc[(df['emd_nm']==row[1]) & (df['dt_of_fr_month']==row[2]) & ((df['dt_of_fr_hour']==row[3]+1) | (df['dt_of_fr_hour']==row[3]-1)),'tmprtr'].mean()

    n['tmprtr']=n.apply(fill_tmprtr,axis=1)
    n.loc[n['tmprtr'].isnull(),'tmprtr']=n.loc[n['tmprtr'].isnull()].apply(fill_tmprtr2, axis=1)
    
    tmp_null_ind=list(n.index)
    df.loc[tmp_null_ind,'tmprtr']=n['tmprtr']
    
    # bldng
    df_cut=df.loc[(df['bldng_ar']<=155.1*2)&(df['bldng_ar']!=0)&(df['ttl_ar']!=0)&(df['bldng_cnt']<=4*2),:]
    def bldcnt3(x):
        if x==1:
            return 0
        elif (x==2) | (x==3):
            return 1
        elif x>=4:
            return 2
    df_cut['bldng_cnt_3']=df_cut['bldng_cnt'].apply(bldcnt3)
    
    # drop1(not using)
    cols=[i for i in df_cut.columns if ('lw_' not in i)&('gas' not in i)&('ele' not in i)]
    df2=df_cut.loc[:,cols]
    dropcol=['bldng_us','bldng_archtctr','lnd_ar','dt_of_athrztn','ttl_grnd_flr','ttl_dwn_flr','bldng_us_clssfctn',
    'prcpttn','id',
    'trgt_crtr','fr_fghtng_fclt_spcl_css_5_yn','fr_fghtng_fclt_spcl_css_6_yn','us_yn','dngrs_thng_yn', 
    'slf_fr_brgd_yn','blk_dngrs_thng_mnfctr_yn','cltrl_hrtg_yn']

    df2.drop(dropcol,axis=1,inplace=True)
    
    ### [Feature Engineering]
    # drop null
    df2.dropna(subset=['rgnl_ar_nm','lnd_us_sttn_nm','rd_sd_nm','emd_nm','fr_mn_cnt','bldng_yrs'],inplace=True)

    # admin cols
    def rg1cat(x):
        if x in ['자연녹지지역', '자연환경보전지역', '보전관리지역', '개발제한구역', '보전녹지지역', '용도미지정', '생산녹지지역', '농림지역']:
            return 0
        elif x in ['계획관리지역', '관리지역']:
            return 1
        elif x in ['제1종일반주거지역', '제1종전용주거지역', '제2종전용주거지역', '제2종일반주거지역', '제3종일반주거지역', '준주거지역']:
            return 2
        elif x in ['일반상업지역','생산관리지역','근린상업지역', '유통상업지역', '중심상업지역']:
            return 3
        elif x in ['일반공업지역', '준공업지역']:
            return 4
        
    #encoder = LabelEncoder()
    #encoder.fit(df2['rgnl_ar_nm'])
    #df2['rgnl_ar_nm_cat']=encoder.transform(df2['rgnl_ar_nm'])
    #print(df2['rgnl_ar_nm_cat'].isna().sum())
    df2['rgnl_ar_nm_cat']=df2['rgnl_ar_nm'].apply(rg1cat)
    
    def jmkcat(x):
        if x in ['차', '체', '장', '사']:
            return 0
        elif x in ['양', '학', '주', '잡', '철', '원']:
            return 1
        elif x in ['창','종','목', '공', '제','유']:
            return 2
        elif x in ['답', '전','임','도','묘','과','구','천','수']:
            return 3
        elif x in ['대']:
            return 4
    encoder = LabelEncoder()
    encoder.fit(df2['jmk'])
    df2['jmk_cat']=encoder.transform(df2['jmk'])
        
    #df2['jmk_cat']=df2['jmk'].apply(jmkcat)
    
    def lndus(x):
        if x in ['고속도로휴게소', '골프장 대중제', '공원묘지', '아파트', '여객자동차터미널', '주차장등']:
            return 0
        else:
            return 1
        #elif x in ['주거나지', '전기타', '주상기타','전', '업무용', '답', '상업기타', '다세대', '공업기타', '상업나지', '연립']:
            #return 1
       #elif x in ['주상나지', '주차장등', '유해.혐오시설', '과수원', '고속도로휴게소', '운동장등', '도로등', '임야기타']:
            #return 2
        #elif x in ['토지임야','하천등','공원등', '위험시설', '조림', '목장용지', '공원묘지', '골프장 대중제', '골프장 회원제', '발전소', '스키장', '유원지','콘도미니엄', '특수기타', '경마장']:
            #return 3
        #else:
            #return 4
        #elif x in ['상업기타','상업나지','상업용','업무용', '공업용','공업기타', '상업기타','공업나지']:
            #return 4
        #elif x in ['유원지', '스키장', '콘도미니엄', '기타', '특수기타','발전소','도로등','골프장 회원제', '골프장 대중제', '공원묘지','운동장등']:
            #return 5
            
    #encoder = LabelEncoder()
    #encoder.fit(df2['lnd_us_sttn_nm'])
    #df2['lnd_us_sttn_nm_cat']=encoder.transform(df2['lnd_us_sttn_nm'])
        
    df2['lnd_us_sttn_nm_cat']=df2['lnd_us_sttn_nm'].apply(lndus)
    
    def rdnm(x):
        if x in ['중로각지', '광대소각', '광대세각']:
            return 0
        elif x in ['중로한면', '소로각지', '광대로한면', '소로한면']:
            return 1
        elif x in ['세로한면(가)','세로각지(가)', '세로각지(불)']:
            return 2
        elif x in ['세로한면(불)', '맹지', '지정되지않음']:
            return 3
        
    encoder = LabelEncoder()
    encoder.fit(df2['rd_sd_nm'])
    df2['rd_sd_nm_cat']=encoder.transform(df2['rd_sd_nm'])    
    #df2['rd_sd_nm_cat']=df2['rd_sd_nm'].apply(rdnm)
#     df2['emd_nm_ct']=df2['emd_nm'].apply(lambda x: str(x)[5:7])

#     eng_name_dict={'거제':'geojesi', '거창':'geochanggun', '고성':'goseonggun', '남해':'namhaegun', '밀양':'miryangsi', '사천':'sacheonsi', '산청':'sancheonggun', '양산':'yangsan', '의령':'uiryeonggun', '진주':'jinjusi', '창녕':'changnyeonggun', '창원':'changwonsi', '통영':'tongyeongsi', '하동':'hadonggun','함안':'hamangun', '함양':'hamyanggun','합천':'hapcheongun'}
#     df2['emd_nm_ct']=df2['emd_nm_ct'].map(eng_name_dict)
    df2['mlt_us_yn_num']=df2['mlt_us_yn'].map({'Y':1,'N':0})
    
    # environment cols
    def slice(st,q1,q2,q3,x):
        if((x>=st) & (x<q1)):
            return 1
        elif((x>=q1) &(x<q2)):
            return 2
        elif((x>=q2)& (x<q3)):
            return 3
        else:
            return 4
    df2["fr_wthr_fclt_dstnc_sl"]=df2['fr_wthr_fclt_dstnc']#.apply(lambda x:slice(0,114,643,2494,x))
    df2["cctv_dstnc_sl"]=df2['cctv_dstnc']#.apply(lambda x:slice(0,100,288,889,x))
    df2["tbc_rtl_str_dstnc_sl"]=df2['tbc_rtl_str_dstnc']#.apply(lambda x:slice(0,527,2184,4958,x))
    df2["ahsm_dstnc_sl"]=df2['ahsm_dstnc']#.apply(lambda x:slice(0,761,3210,14239,x))
    df2["no_tbc_zn_dstnc_sl"]=df2['no_tbc_zn_dstnc']#.apply(lambda x:slice(0,155,422,1486,x))
    ###[fill null and cut]
    
    ###[create X, y]
    using=['bldng_cnt_3','bldng_ar','ttl_ar','tmprtr', 'wnd_spd', 'hmdt', 'wnd_dr8','bldng_yrs',
          'rgnl_ar_nm_cat', 'jmk_cat', 'lnd_us_sttn_nm_cat', 'rd_sd_nm_cat', 'emd_nm_ct','fr_sttn_dstnc',
          'fr_wthr_fclt_dstnc_sl','fr_mn_cnt', 'mlt_us_yn_num','cctv_dstnc_sl', 'tbc_rtl_str_dstnc_sl', 'ahsm_dstnc_sl', 
          'no_tbc_zn_dstnc_sl','sft_emrgnc_bll_dstnc',
          'fr_yn']

    df_use=df2.loc[:,using]

    #ohe_wnd = pd.get_dummies(df_use['wnd_dr8']) 
    #df_use=pd.concat([df_use, ohe_wnd], axis=1) 
    del df_use['wnd_dr8'] 
    
    #ohe_emd = pd.get_dummies(df_use['emd_nm_ct'])
    #df_final=pd.concat([df_use, ohe_emd], axis=1) 
    del df_use['emd_nm_ct'] 
    #del df_final['ttl_ar']
    #del df_final['hmdt']
    #del df_final['wnd_spd']
    del df_use['mlt_us_yn_num']
    del df_use['jmk_cat']
    del df_use['rgnl_ar_nm_cat']
    df_final = df_use
    
    df_final = df_final.reset_index(drop=True)
    
    #scaler = MinMaxScaler()
    #fr_sttn_scale=df_final['fr_sttn_dstnc'].values.reshape(-1,1)
    #scaler.fit(fr_sttn_scale)
    #a = pd.Series(scaler.transform(fr_sttn_scale).flatten())
    #df_final['fr_sttn_dstnc'] = a
    #df_final['fr_sttn_dstnc'] = df_final['fr_sttn_dstnc'].apply(lambda x: np.log(1+x))
    
    #scaler = MinMaxScaler()
    #print(df_final['fr_sttn_dstnc'].isna().sum())
    #fr_sttn_scale=df_final['sft_emrgnc_bll_dstnc'].values.reshape(-1,1)
    #scaler.fit(fr_sttn_scale)
    #a = pd.Series(scaler.transform(fr_sttn_scale).flatten())
    #pd.Series(scaler.transform(fr_sttn_scale))
    #df_final['sft_emrgnc_bll_dstnc'] = a
    #df_final['sft_emrgnc_bll_dstnc'] = df_final['sft_emrgnc_bll_dstnc'].apply(lambda x: np.log(1+x))
    
    #df_final['ttl_ar'] = df_final['ttl_ar'].apply(lambda x: np.log(1+x))

    X=df_final.drop(['fr_yn'],axis=1)
    y=df_final['fr_yn']
    print(X.isna().sum())
    ###[create X, y]
    
    if 'train' in file:
        smote=SMOTE(random_state=0)
        X_over,y_over=smote.fit_sample(X,y)
        return X_over, y_over
        #return X,y
    else:
        return X,y

# %%
def get_clf_eval(y_test,y_pred):
    plt.figure(figsize=(16,6))
    accuracy=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1 = f1_score(y_test, y_pred)
#     print(classification_report(y_test, y_pred)
    print('정확도: {0:.4f} 정밀도: {1:.4f} 재현율: {2:,.4f} f1 : {3:.3f}'.format(accuracy, precision, recall, f1))
    print(classification_report(y_test, y_pred))
def get_model_train_eval(model,i):
    model.fit(X_train,y_train)
    #modeling 함수 for문으로
    y_proba=model.predict_proba(X_test) 
    y_pred=model.predict(X_test)
    return y_proba

def determine_y(x,threshold):
    if x>=threshold:
        return 1
    else:
        return 0
def predy(x,threshold):
    y_list=[]
    for i in x:
        y_list.append(determine_y(i,threshold))
    return y_list

# %%
X_train, y_train=preprocessing_data('PJT002_train.csv')
X_test, y_test=preprocessing_data('PJT002_validation.csv')
X_train = pd.DataFrame(X_train,columns=X_test.columns)
y_train = pd.DataFrame(y_train,columns=['fr_yn'])
# Out:
# bldng_cnt_3              0
# bldng_ar                 0
# ttl_ar                   0
# tmprtr                   0
# wnd_spd                  0
# hmdt                     0
# bldng_yrs                0
# lnd_us_sttn_nm_cat       0
# rd_sd_nm_cat             0
# fr_sttn_dstnc            0
# fr_wthr_fclt_dstnc_sl    0
# fr_mn_cnt                0
# cctv_dstnc_sl            0
# tbc_rtl_str_dstnc_sl     0
# ahsm_dstnc_sl            0
# no_tbc_zn_dstnc_sl       0
# sft_emrgnc_bll_dstnc     0
# dtype: int64
# bldng_cnt_3              0
# bldng_ar                 0
# ttl_ar                   0
# tmprtr                   0
# wnd_spd                  0
# hmdt                     0
# bldng_yrs                0
# lnd_us_sttn_nm_cat       0
# rd_sd_nm_cat             0
# fr_sttn_dstnc            0
# fr_wthr_fclt_dstnc_sl    0
# fr_mn_cnt                0
# cctv_dstnc_sl            0
# tbc_rtl_str_dstnc_sl     0
# ahsm_dstnc_sl            0
# no_tbc_zn_dstnc_sl       0
# sft_emrgnc_bll_dstnc     0
# dtype: int64

# %%
print(X_train.shape, y_train.shape,X_test.shape,y_test.shape)
# Out:
# (39846, 17) (39846, 1) (3755, 17) (3755,)

# %%
X_train.describe()
# Out:
#         bldng_cnt    bldng_ar      ttl_ar      tmprtr     wnd_spd        hmdt   bldng_yrs  rgnl_ar_nm_cat  lnd_us_sttn_nm_cat  rd_sd_nm_cat  fr_sttn_dstnc  fr_wthr_fclt_dstnc_sl   fr_mn_cnt  cctv_dstnc_sl  tbc_rtl_str_dstnc_sl  ahsm_dstnc_sl  no_tbc_zn_dstnc_sl  sft_emrgnc_bll_dstnc
# count 39846.00000 39846.00000 39846.00000 39846.00000 39846.00000 39846.00000 39846.00000     39846.00000         39846.00000   39846.00000    39846.00000            39846.00000 39846.00000    39846.00000           39846.00000    39846.00000         39846.00000           39846.00000
# mean      2.30479   111.03351   172.27981    13.99014     1.65626    61.64999    34.33836         7.81336            13.52989       6.94883     5555.75507             1391.07992   151.01150      738.82596            3079.03121     9944.67933          1007.51787           33721.96399
# std       1.44992    58.72098   246.54166     9.25155     1.24743    22.79077   107.33975         6.52999             7.47355       1.74781     4967.55553             2196.00857    37.98649     1383.35463            3312.82998    11894.61813          1626.97179           24810.09318
# min       1.00000     3.31000     3.31000   -14.10000     0.00000     0.00000 -7971.00000         0.00000             0.00000       0.00000        4.00000                0.00000    85.00000        0.00000               0.00000        0.00000             0.00000               8.00000
# 25%       1.00000    68.88000    73.34043     6.61188     0.70000    44.00000    17.00000         1.00000             9.00000       6.00000     1514.00000               86.00000   112.00000       90.00000             429.24425      755.00064            75.00000           12430.00000
# 50%       2.00000    97.70694   110.70000    14.35564     1.40000    62.00000    27.67788         7.00000             9.00000       7.00000     4012.00000              343.00000   161.00000      237.04186            1859.29485     3672.00000           311.00000           31826.00000
# 75%       3.00000   140.00000   194.41793    21.40000     2.32936    81.00000    50.79845        14.07037            16.00000       8.00000     8404.75000             1634.24103   194.00000      814.56853            4745.48808    17150.00000          1202.28510           48821.20151
# max       8.00000   310.13000 18590.09000    37.90000    13.90000   100.00000   268.00000        21.00000            34.00000      11.00000    35243.00000            13940.00000   210.00000    12278.00000           20186.00000    55273.00000         11993.00000          103424.00000

# %%
X_test.describe()
# Out:
#        bldng_cnt   bldng_ar     ttl_ar     tmprtr    wnd_spd       hmdt  bldng_yrs  rgnl_ar_nm_cat  lnd_us_sttn_nm_cat  rd_sd_nm_cat  fr_sttn_dstnc  fr_wthr_fclt_dstnc_sl  fr_mn_cnt  cctv_dstnc_sl  tbc_rtl_str_dstnc_sl  ahsm_dstnc_sl  no_tbc_zn_dstnc_sl  sft_emrgnc_bll_dstnc
# count 3755.00000 3755.00000 3755.00000 3755.00000 3755.00000 3755.00000 3755.00000      3755.00000          3755.00000    3755.00000     3755.00000             3755.00000 3755.00000     3755.00000            3755.00000     3755.00000          3755.00000            3755.00000
# mean     1.43196  132.04865  259.37130   14.98094    2.12886   61.97736   28.34967         8.45300            14.22237       7.30626     2087.04794              206.50146  191.34061      220.86152             905.71398    14830.71318           670.38615            1903.38189
# std      0.85080   65.39743  259.71300    9.09185    1.47852   22.84767   24.86088         3.79890             7.56308       2.14274     1349.60369              286.97962   11.35326      262.56944            1098.45875     6688.00928           759.24090            2470.36587
# min      1.00000    4.75000    4.75000  -12.20000    0.00000    0.00000    1.00000         0.00000             0.00000       0.00000        3.00000                0.00000  178.00000        1.00000               0.00000      861.00000             2.00000               3.00000
# 25%      1.00000   82.65500   92.91000    7.90000    1.00000   44.00000   11.00000         8.00000             9.00000       6.00000      972.00000               63.00000  178.00000       67.00000             198.00000     8852.50000           165.00000             214.00000
# 50%      1.00000  122.36000  180.16000   15.80000    1.80000   62.00000   22.00000        10.00000             9.00000       7.00000     1855.00000              108.00000  201.00000      114.00000             409.00000    16325.00000           303.00000             584.00000
# 75%      2.00000  167.28000  352.18000   22.00000    3.05000   80.00000   33.00000        11.00000            23.00000       9.00000     2971.00000              208.00000  201.00000      258.50000            1234.00000    19218.50000           950.50000            2853.00000
# max      8.00000  308.72000 2892.19400   37.20000   10.70000  100.00000  218.00000        16.00000            29.00000      12.00000     7274.00000             2692.00000  201.00000     1975.00000            7366.00000    32032.00000          3674.00000           12049.00000

# %%
sns.distplot(X_train.loc[y_train['fr_yn']==0,['wnd_spd']],kde=True)

# %%
X_train.loc[y_train['fr_yn']==0,['wnd_spd']].describe()
# Out:
#           wnd_spd
# count 19923.00000
# mean      1.50990
# std       1.26070
# min       0.00000
# 25%       0.60000
# 50%       1.20000
# 75%       2.20000
# max      13.90000

# %%
sns.distplot(X_test.loc[y_test==0,['wnd_spd']],kde=True)

# %%
X_test.loc[y_test==0,['wnd_spd']].describe()
# Out:
#          wnd_spd
# count 3275.00000
# mean     2.07933
# std      1.45240
# min      0.00000
# 25%      1.00000
# 50%      1.70000
# 75%      3.00000
# max     10.70000

# %%
evals = [(X_test, y_test)]
xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=8)
xgb_wrapper.fit(X_train , y_train,  early_stopping_rounds=200,eval_set=evals, eval_metric="auc",  verbose=True)
w_preds = xgb_wrapper.predict(X_test)
get_clf_eval(y_test,w_preds)
# Out:
# [0]	validation_0-auc:0.585801
# Will train until validation_0-auc hasn't improved in 200 rounds.
# [1]	validation_0-auc:0.579114
# [2]	validation_0-auc:0.592029
# [3]	validation_0-auc:0.591202
# [4]	validation_0-auc:0.593625
# [5]	validation_0-auc:0.596454
# [6]	validation_0-auc:0.597577
# [7]	validation_0-auc:0.59859
# [8]	validation_0-auc:0.598565
# [9]	validation_0-auc:0.600023
# [10]	validation_0-auc:0.60237
# [11]	validation_0-auc:0.604985
# [12]	validation_0-auc:0.60495
# [13]	validation_0-auc:0.606839
# [14]	validation_0-auc:0.606092
# [15]	validation_0-auc:0.606872
# [16]	validation_0-auc:0.608931
# [17]	validation_0-auc:0.610105
# [18]	validation_0-auc:0.611626
# [19]	validation_0-auc:0.611124
# [20]	validation_0-auc:0.611717
# [21]	validation_0-auc:0.613734
# [22]	validation_0-auc:0.614195
# [23]	validation_0-auc:0.615234
# [24]	validation_0-auc:0.615056
# [25]	validation_0-auc:0.615739
# [26]	validation_0-auc:0.614613
# [27]	validation_0-auc:0.615363
# [28]	validation_0-auc:0.615503
# [29]	validation_0-auc:0.615833
# [30]	validation_0-auc:0.617165
# [31]	validation_0-auc:0.61819
# [32]	validation_0-auc:0.618432
# [33]	validation_0-auc:0.618349
# [34]	validation_0-auc:0.61926
# [35]	validation_0-auc:0.618847
# [36]	validation_0-auc:0.618688
# [37]	validation_0-auc:0.618704
# [38]	validation_0-auc:0.618597
# [39]	validation_0-auc:0.617388
# [40]	validation_0-auc:0.616354
# [41]	validation_0-auc:0.617671
# [42]	validation_0-auc:0.617312
# [43]	validation_0-auc:0.616509
# [44]	validation_0-auc:0.61602
# [45]	validation_0-auc:0.615733
# [46]	validation_0-auc:0.616001
# [47]	validation_0-auc:0.616642
# [48]	validation_0-auc:0.617195
# [49]	validation_0-auc:0.617923
# [50]	validation_0-auc:0.617517
# [51]	validation_0-auc:0.617769
# [52]	validation_0-auc:0.617683
# [53]	validation_0-auc:0.617797
# [54]	validation_0-auc:0.617787
# [55]	validation_0-auc:0.617843
# [56]	validation_0-auc:0.618164
# [57]	validation_0-auc:0.617913
# [58]	validation_0-auc:0.618121
# [59]	validation_0-auc:0.616414
# [60]	validation_0-auc:0.615579
# [61]	validation_0-auc:0.615069
# [62]	validation_0-auc:0.615234
# [63]	validation_0-auc:0.615277
# [64]	validation_0-auc:0.612063
# [65]	validation_0-auc:0.611935
# [66]	validation_0-auc:0.612075
# [67]	validation_0-auc:0.611998
# [68]	validation_0-auc:0.612837
# [69]	validation_0-auc:0.612946
# [70]	validation_0-auc:0.612843
# [71]	validation_0-auc:0.610913
# [72]	validation_0-auc:0.610545
# [73]	validation_0-auc:0.610207
# [74]	validation_0-auc:0.610437
# [75]	validation_0-auc:0.610275
# [76]	validation_0-auc:0.609912
# [77]	validation_0-auc:0.610069
# [78]	validation_0-auc:0.61118
# [79]	validation_0-auc:0.611133
# [80]	validation_0-auc:0.610501
# [81]	validation_0-auc:0.609941
# [82]	validation_0-auc:0.609961
# [83]	validation_0-auc:0.610067
# [84]	validation_0-auc:0.610012
# [85]	validation_0-auc:0.609651
# [86]	validation_0-auc:0.609686
# [87]	validation_0-auc:0.610527
# [88]	validation_0-auc:0.610211
# [89]	validation_0-auc:0.610288
# [90]	validation_0-auc:0.610393
# [91]	validation_0-auc:0.610557
# [92]	validation_0-auc:0.610485
# [93]	validation_0-auc:0.61083
# [94]	validation_0-auc:0.610819
# [95]	validation_0-auc:0.610559
# [96]	validation_0-auc:0.611089
# [97]	validation_0-auc:0.611334
# [98]	validation_0-auc:0.610802
# [99]	validation_0-auc:0.610801
# [100]	validation_0-auc:0.610369
# [101]	validation_0-auc:0.610218
# [102]	validation_0-auc:0.610112
# [103]	validation_0-auc:0.610067
# [104]	validation_0-auc:0.610038
# [105]	validation_0-auc:0.609834
# [106]	validation_0-auc:0.609862
# [107]	validation_0-auc:0.609365
# [108]	validation_0-auc:0.608831
# [109]	validation_0-auc:0.609347
# [110]	validation_0-auc:0.609069
# [111]	validation_0-auc:0.608767
# [112]	validation_0-auc:0.608573
# [113]	validation_0-auc:0.608573
# [114]	validation_0-auc:0.608811
# [115]	validation_0-auc:0.609275
# [116]	validation_0-auc:0.60944
# [117]	validation_0-auc:0.608482
# [118]	validation_0-auc:0.608153
# [119]	validation_0-auc:0.608249
# [120]	validation_0-auc:0.608108
# [121]	validation_0-auc:0.607547
# [122]	validation_0-auc:0.607294
# [123]	validation_0-auc:0.607295
# [124]	validation_0-auc:0.606878
# [125]	validation_0-auc:0.607322
# [126]	validation_0-auc:0.60724
# [127]	validation_0-auc:0.607209
# [128]	validation_0-auc:0.607869
# [129]	validation_0-auc:0.607097
# [130]	validation_0-auc:0.606877
# [131]	validation_0-auc:0.606891
# [132]	validation_0-auc:0.607843
# [133]	validation_0-auc:0.607765
# [134]	validation_0-auc:0.608166
# [135]	validation_0-auc:0.608294
# [136]	validation_0-auc:0.608064
# [137]	validation_0-auc:0.608189
# [138]	validation_0-auc:0.608073
# [139]	validation_0-auc:0.607975
# [140]	validation_0-auc:0.607992
# [141]	validation_0-auc:0.608012
# [142]	validation_0-auc:0.608012
# [143]	validation_0-auc:0.608088
# [144]	validation_0-auc:0.608088
# [145]	validation_0-auc:0.607674
# [146]	validation_0-auc:0.607703
# [147]	validation_0-auc:0.607852
# [148]	validation_0-auc:0.607709
# [149]	validation_0-auc:0.607414
# [150]	validation_0-auc:0.60745
# [151]	validation_0-auc:0.607536
# [152]	validation_0-auc:0.607071
# [153]	validation_0-auc:0.607714
# [154]	validation_0-auc:0.607714
# [155]	validation_0-auc:0.607714
# [156]	validation_0-auc:0.607955
# [157]	validation_0-auc:0.608137
# [158]	validation_0-auc:0.608164
# [159]	validation_0-auc:0.608246
# [160]	validation_0-auc:0.608268
# [161]	validation_0-auc:0.608269
# [162]	validation_0-auc:0.608801
# [163]	validation_0-auc:0.607982
# [164]	validation_0-auc:0.606203
# [165]	validation_0-auc:0.606037
# [166]	validation_0-auc:0.606231
# [167]	validation_0-auc:0.606292
# [168]	validation_0-auc:0.606492
# [169]	validation_0-auc:0.606489
# [170]	validation_0-auc:0.606577
# [171]	validation_0-auc:0.60682
# [172]	validation_0-auc:0.60694
# [173]	validation_0-auc:0.606977
# [174]	validation_0-auc:0.607035
# [175]	validation_0-auc:0.60691
# [176]	validation_0-auc:0.607137
# [177]	validation_0-auc:0.606974
# [178]	validation_0-auc:0.607401
# [179]	validation_0-auc:0.607765
# [180]	validation_0-auc:0.607704
# [181]	validation_0-auc:0.607126
# [182]	validation_0-auc:0.607055
# [183]	validation_0-auc:0.607202
# [184]	validation_0-auc:0.607487
# [185]	validation_0-auc:0.60751
# [186]	validation_0-auc:0.607525
# [187]	validation_0-auc:0.607571
# [188]	validation_0-auc:0.607534
# [189]	validation_0-auc:0.606485
# [190]	validation_0-auc:0.60679
# [191]	validation_0-auc:0.60679
# [192]	validation_0-auc:0.606714
# [193]	validation_0-auc:0.606683
# [194]	validation_0-auc:0.606551
# [195]	validation_0-auc:0.606724
# [196]	validation_0-auc:0.60648
# [197]	validation_0-auc:0.6069
# [198]	validation_0-auc:0.607503
# [199]	validation_0-auc:0.607282
# [200]	validation_0-auc:0.607282
# [201]	validation_0-auc:0.607192
# [202]	validation_0-auc:0.606961
# [203]	validation_0-auc:0.606204
# [204]	validation_0-auc:0.605399
# [205]	validation_0-auc:0.605563
# [206]	validation_0-auc:0.605391
# [207]	validation_0-auc:0.605849
# [208]	validation_0-auc:0.606175
# [209]	validation_0-auc:0.605936
# [210]	validation_0-auc:0.606416
# [211]	validation_0-auc:0.606569
# [212]	validation_0-auc:0.606716
# [213]	validation_0-auc:0.605993
# [214]	validation_0-auc:0.606193
# [215]	validation_0-auc:0.606051
# [216]	validation_0-auc:0.606049
# [217]	validation_0-auc:0.606053
# [218]	validation_0-auc:0.606382
# [219]	validation_0-auc:0.605939
# [220]	validation_0-auc:0.606078
# [221]	validation_0-auc:0.606187
# [222]	validation_0-auc:0.606343
# [223]	validation_0-auc:0.606391
# [224]	validation_0-auc:0.606795
# [225]	validation_0-auc:0.606795
# [226]	validation_0-auc:0.606975
# [227]	validation_0-auc:0.606041
# [228]	validation_0-auc:0.606071
# [229]	validation_0-auc:0.605976
# [230]	validation_0-auc:0.60603
# [231]	validation_0-auc:0.606084
# [232]	validation_0-auc:0.606084
# [233]	validation_0-auc:0.606086
# [234]	validation_0-auc:0.605587
# Stopping. Best iteration:
# [34]	validation_0-auc:0.61926
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=8,
#               min_child_weight=1, missing=None, n_estimators=400, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)
# 정확도: 0.7060 정밀도: 0.1823 재현율: 0.3729 f1 : 0.245
#               precision    recall  f1-score   support
#
#            0       0.89      0.75      0.82      3275
#            1       0.18      0.37      0.24       480
#
#     accuracy                           0.71      3755
#    macro avg       0.54      0.56      0.53      3755
# weighted avg       0.80      0.71      0.74      3755

# %%
plt.figure(figsize=(40,50))
plot_importance(xgb_wrapper)

# %%
fr_sttn_dstnc
sft_emrgnc_bll_dstnc
tmprtr
bldng_ar
ttl_ar
hmdt
wnd_spd
rgnl_ar_nm_cat
cctv_dstnc_sl
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-425-077da18a9b8a> in <module>
# ----> 1 fr_sttn_dstnc
#       2 sft_emrgnc_bll_dstnc
#       3 tmprtr
#       4 bldng_ar
#       5 ttl_ar
#
# NameError: name 'fr_sttn_dstnc' is not defined

# %%
xgb_clf=XGBClassifier(objective='binary:logistic')

#X_train, X_test, y_train, y_test = train_test_split(X_list[i], Y_list[i],test_size = 0.2)
evals = [(X_test, y_test)]
estimator = xgb_clf
parameters = {
    'max_depth': range (2, 10, 1),
    'n_estimators': range(60, 220, 40),
    'learning_rate': [0.1, 0.01, 0.05]
 }

grid_search = GridSearchCV(
    estimator=estimator,
    param_grid=parameters,
    scoring = 'f1',
    n_jobs = 10,
    cv = 3,
    verbose=True
)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 96 candidates, totalling 288 fits
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-224-eb8786e1e329> in <module>
#      19 )
#      20
# ---> 21 grid_search.fit(X_train, y_train)
#
# C:\Users\jaeyong\Anaconda3\envs\cuda\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     685                 return results
#     686
# --> 687             self._run_search(evaluate_candidates)
#     688
#     689         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# C:\Users\jaeyong\Anaconda3\envs\cuda\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1146     def _run_search(self, evaluate_candidates):
#    1147         """Search all candidates in param_grid"""
# -> 1148         evaluate_candidates(ParameterGrid(self.param_grid))
#    1149
#    1150
#
# C:\Users\jaeyong\Anaconda3\envs\cuda\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     664                                for parameters, (train, test)
#     665                                in product(candidate_params,
# --> 666                                           cv.split(X, y, groups)))
#     667
#     668                 if len(out) < 1:
#
# C:\Users\jaeyong\Anaconda3\envs\cuda\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     932
#     933             with self._backend.retrieval_context():
# --> 934                 self.retrieve()
#     935             # Make sure that we get a last message telling us we are done
#     936             elapsed_time = time.time() - self._start_time
#
# C:\Users\jaeyong\Anaconda3\envs\cuda\lib\site-packages\joblib\parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# C:\Users\jaeyong\Anaconda3\envs\cuda\lib\site-packages\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# C:\Users\jaeyong\Anaconda3\envs\cuda\lib\concurrent\futures\_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# C:\Users\jaeyong\Anaconda3\envs\cuda\lib\threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
print(grid_search.best_params_)

print(grid_search.best_score_)

# %%
proba = grid_search.best_estimator_.predict_proba(X_test.values)
pred = predy(proba[:,1],0.5)
get_clf_eval(y_test,pred)
